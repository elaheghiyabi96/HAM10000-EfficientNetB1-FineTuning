# %%
from google.colab import drive
import os

print("Mounting Google Drive...")
drive.mount('/content/drive')
print("Google Drive mounted successfully.")

# Assuming HAM10000 is in archive2.zip
zip_path = '/content/drive/MyDrive/archive2.zip'

if os.path.exists(zip_path):
    print("\nUnzipping ham10000 dataset...")
    os.makedirs('ham10000_data', exist_ok=True)
    os.system(f'unzip -q "{zip_path}" -d ham10000_data/')
    print("Unzipping completed successfully.")
else:
    print(f"\nError: The file was not found at the specified path: {zip_path}")
# Out:
# Mounting Google Drive...
# Mounted at /content/drive
# Google Drive mounted successfully.
#
# Unzipping ham10000 dataset...
# Unzipping completed successfully.

# %%
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

# --- Define Parameters ---
base_dir = 'ham10000_data'
IMG_SIZE = 224 # EfficientNetB1 uses 240, but 224 is fine for transfer learning
BATCH_SIZE = 64
NUM_CLASSES = 7
EPOCHS = 40

# --- Load Data with Pandas ---
print("Loading metadata from HAM10000_metadata.csv...")
metadata_df = pd.read_csv(os.path.join(base_dir, 'HAM10000_metadata.csv'))

# --- Create a dictionary of all image paths ---
image_folders = [os.path.join(base_dir, f) for f in os.listdir(base_dir) if 'images' in f]
all_image_paths = {os.path.splitext(f)[0]: os.path.join(folder, f) for folder in image_folders for f in os.listdir(folder)}
metadata_df['image_path'] = metadata_df['image_id'].map(all_image_paths.get)

# --- Convert text labels to numbers (0, 1, 2...) ---
class_names = sorted(metadata_df['dx'].unique())
label_map = {label: i for i, label in enumerate(class_names)}
metadata_df['label'] = metadata_df['dx'].map(label_map.get)

# --- Split Data into Training and Validation ---
train_df, val_df = train_test_split(
    metadata_df, test_size=0.2, random_state=42, stratify=metadata_df['label']
)
print(f"Training samples: {len(train_df)}, Validation samples: {len(val_df)}")

# --- Calculate Class Weights ---
class_weights = compute_class_weight('balanced', classes=np.unique(train_df['label']), y=train_df['label'])
class_weights_dict = dict(enumerate(class_weights))
print("Calculated Class Weights:", class_weights_dict)

# --- Create tf.data.Dataset pipeline ---
def load_and_preprocess_image(path, label):
    image = tf.io.read_file(path)
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.resize(image, [IMG_SIZE, IMG_SIZE])
    return image, label

AUTOTUNE = tf.data.AUTOTUNE
train_dataset = tf.data.Dataset.from_tensor_slices((train_df['image_path'], train_df['label']))
train_dataset = train_dataset.map(load_and_preprocess_image, num_parallel_calls=AUTOTUNE)
train_dataset = train_dataset.shuffle(1024).batch(BATCH_SIZE).prefetch(AUTOTUNE)

validation_dataset = tf.data.Dataset.from_tensor_slices((val_df['image_path'], val_df['label']))
validation_dataset = validation_dataset.map(load_and_preprocess_image, num_parallel_calls=AUTOTUNE)
validation_dataset = validation_dataset.batch(BATCH_SIZE).prefetch(AUTOTUNE)

print("\nImage-only datasets created successfully.")
# Out:
# Loading metadata from HAM10000_metadata.csv...
# Training samples: 8012, Validation samples: 2003
# Calculated Class Weights: {0: np.float64(4.368593238822246), 1: np.float64(2.7848453249913105), 2: np.float64(1.3021290427433772), 3: np.float64(12.440993788819876), 4: np.float64(1.2860353130016051), 5: np.float64(0.21338020666879728), 6: np.float64(10.040100250626567)}
#
# Image-only datasets created successfully.

# %%
import tensorflow as tf

# Data augmentation layer remains the same
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal_and_vertical"),
    tf.keras.layers.RandomRotation(0.3),
    tf.keras.layers.RandomZoom(height_factor=0.2, width_factor=0.2),
    tf.keras.layers.RandomBrightness(factor=0.2),
    tf.keras.layers.RandomContrast(factor=0.2)
], name="data_augmentation")

# Load EfficientNetB1 as the base model
base_model = tf.keras.applications.EfficientNetB1(
    include_top=False,
    weights='imagenet',
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)
base_model.trainable = False

# Build the model
inputs = tf.keras.layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3))

# Preprocessing for EfficientNet remains the same
x = tf.keras.applications.efficientnet.preprocess_input(inputs)
x = data_augmentation(x)

x = base_model(x, training=False)
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Dropout(0.2)(x)
outputs = tf.keras.layers.Dense(NUM_CLASSES, activation='softmax')(x)

model = tf.keras.Model(inputs, outputs)

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb1_notop.h5
# 27018416/27018416 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ data_augmentation (Sequential)  │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb1 (Functional)     │ (None, 7, 7, 1280)     │     6,575,239 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 7)              │         8,967 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,584,206 (25.12 MB)
#  Trainable params: 8,967 (35.03 KB)
#  Non-trainable params: 6,575,239 (25.08 MB)

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Compile the model
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Define EarlyStopping
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

# Start training
print("\nStarting model training with EfficientNetB1...")
history = model.fit(
    train_dataset,
    epochs=EPOCHS,
    validation_data=validation_dataset,
    class_weight=class_weights_dict,
    callbacks=[early_stopping]
)
print("\nModel training finished.")

# Enhanced Final Evaluation
print("\nStarting final evaluation...")
loss, accuracy = model.evaluate(validation_dataset)

print("\n" + "="*40)
print("     Final Results on the Validation Set (EfficientNetB1)")
print("="*40)
print(f"Loss: {loss:.4f}")
print(f"Accuracy: {accuracy * 100:.2f}%")
print("="*40)

# Detailed Classification Report
print("\n" + "="*50)
print("     Detailed Classification Report")
print("="*50)
true_labels = np.concatenate([y for x, y in validation_dataset], axis=0)
predictions = model.predict(validation_dataset)
predicted_labels = np.argmax(predictions, axis=1)
report = classification_report(true_labels, predicted_labels, target_names=class_names)
print(report)

# Confusion Matrix
print("\n" + "="*50)
print("     Confusion Matrix")
print("="*50)
cm = confusion_matrix(true_labels, predicted_labels)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix for EfficientNetB1 Model')
plt.show()
# Out:
# Starting model training with EfficientNetB1...
# Epoch 1/40
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 108s 568ms/step - accuracy: 0.3714 - loss: 1.8445 - val_accuracy: 0.5637 - val_loss: 1.2562
# Epoch 2/40
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 115s 395ms/step - accuracy: 0.5110 - loss: 1.4148 - val_accuracy: 0.6370 - val_loss: 1.0414
# Epoch 3/40
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 80s 392ms/step - accuracy: 0.5588 - loss: 1.3188 - val_accuracy: 0.6445 - val_loss: 1.0341
# Epoch 4/40
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 82s 392ms/step - accuracy: 0.5580 - loss: 1.2553 - val_accuracy: 0.6011 - val_loss: 1.0636
# Epoch 5/40
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 81s 372ms/step - accuracy: 0.5579 - loss: 1.1898 - val_accuracy: 0.6650 - val_loss: 0.9175
# Epoch 6/40
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 83s 391ms/step - accuracy: 0.5822 - loss: 1.1686 - val_accuracy: 0.6810 - val_loss: 0.8849
# Epoch 7/40
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 55s 402ms/step - accuracy: 0.6063 - loss: 1.1379 - val_accuracy: 0.6440 - val_loss: 0.9485
# Epoch 8/40
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 54s 394ms/step - accuracy: 0.5844 - loss: 1.1033 - val_accuracy: 0.6600 - val_loss: 0.9190
# Epoch 9/40
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 52s 381ms/step - accuracy: 0.5941 - loss: 1.1043 - val_accuracy: 0.6595 - val_loss: 0.9145
# Epoch 10/40
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 85s 406ms/step - accuracy: 0.5953 - loss: 1.1282 - val_accuracy: 0.6800 - val_loss: 0.8991
# Epoch 11/40
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.5912 - loss: 1.0840
# Model training finished.
#
# Starting final evaluation...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 319ms/step - accuracy: 0.6602 - loss: 0.9187
#
# ========================================
#      Final Results on the Validation Set (EfficientNetB1)
# ========================================
# Loss: 0.8849
# Accuracy: 68.10%
# ========================================
#
# ==================================================
#      Detailed Classification Report
# ==================================================
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 18s 403ms/step
#               precision    recall  f1-score   support
#
#        akiec       0.50      0.15      0.24        65
#          bcc       0.45      0.56      0.50       103
#          bkl       0.51      0.51      0.51       220
#           df       0.15      0.83      0.25        23
#          mel       0.35      0.63      0.45       223
#           nv       0.94      0.75      0.84      1341
#         vasc       0.44      0.68      0.54        28
#
#     accuracy                           0.68      2003
#    macro avg       0.48      0.59      0.47      2003
# weighted avg       0.77      0.68      0.71      2003
#
#
# ==================================================
#      Confusion Matrix
# ==================================================

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf

# --- Start of the Fine-Tuning Process ---

# The 'base_model' variable should still hold the EfficientNetB1 instance
base_model.trainable = True

# Let's unfreeze the top 30 layers for fine-tuning.
fine_tune_at = len(base_model.layers) - 30

# Freeze all the layers before the `fine_tune_at` layer
for layer in base_model.layers[:fine_tune_at]:
    layer.trainable = False

# Re-compile the model with a very low learning rate
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-6),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

print("\nEfficientNetB1 model re-compiled for fine-tuning.")
model.summary()


# Continue training the model to fine-tune it
print("\nStarting fine-tuning for EfficientNetB1...")

fine_tune_epochs = 20
# Set the total number of epochs for the entire process
total_epochs = history.epoch[-1] + 1 + fine_tune_epochs

# We use the same EarlyStopping callback
history_fine = model.fit(
    train_dataset,
    epochs=total_epochs,
    initial_epoch=history.epoch[-1] + 1,
    validation_data=validation_dataset,
    callbacks=[early_stopping]
)

# --- Final evaluation after fine-tuning ---
print("\nStarting final evaluation after fine-tuning EfficientNetB1...")
loss, accuracy = model.evaluate(validation_dataset)

print("\n" + "="*40)
print("     Final Results After Fine-Tuning EfficientNetB1")
print("="*40)
print(f"Loss: {loss:.4f}")
print(f"Accuracy: {accuracy * 100:.2f}%")
print("="*40)

# Detailed Classification Report
print("\n" + "="*50)
print("     Detailed Classification Report")
print("="*50)
true_labels = np.concatenate([y for x, y in validation_dataset], axis=0)
predictions = model.predict(validation_dataset)
predicted_labels = np.argmax(predictions, axis=1)
report = classification_report(true_labels, predicted_labels, target_names=class_names)
print(report)

# Confusion Matrix
print("\n" + "="*50)
print("     Confusion Matrix")
print("="*50)
cm = confusion_matrix(true_labels, predicted_labels)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix for Fine-Tuned EfficientNetB1')
plt.show()
# Out:
# EfficientNetB1 model re-compiled for fine-tuning.
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ data_augmentation (Sequential)  │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb1 (Functional)     │ (None, 7, 7, 1280)     │     6,575,239 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 7)              │         8,967 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,584,206 (25.12 MB)
#  Trainable params: 2,480,775 (9.46 MB)
#  Non-trainable params: 4,103,431 (15.65 MB)
# Starting fine-tuning for EfficientNetB1...
# Epoch 12/31
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 88s 441ms/step - accuracy: 0.2626 - loss: 2.0496 - val_accuracy: 0.4853 - val_loss: 1.4180
# Epoch 13/31
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 56s 400ms/step - accuracy: 0.2938 - loss: 1.9557 - val_accuracy: 0.3909 - val_loss: 1.6450
# Epoch 14/31
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 82s 415ms/step - accuracy: 0.3349 - loss: 1.8341 - val_accuracy: 0.4044 - val_loss: 1.5967
# Epoch 15/31
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 56s 414ms/step - accuracy: 0.3624 - loss: 1.7372 - val_accuracy: 0.4408 - val_loss: 1.4935
# Epoch 16/31
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 91s 487ms/step - accuracy: 0.3901 - loss: 1.6518 - val_accuracy: 0.4828 - val_loss: 1.3932
# Epoch 17/31
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 56s 412ms/step - accuracy: 0.4232 - loss: 1.5717 - val_accuracy: 0.5247 - val_loss: 1.3090
# Epoch 18/31
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 55s 395ms/step - accuracy: 0.4657 - loss: 1.4950 - val_accuracy: 0.5607 - val_loss: 1.2277
# Epoch 19/31
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 56s 403ms/step - accuracy: 0.4824 - loss: 1.4471 - val_accuracy: 0.5896 - val_loss: 1.1658
# Epoch 20/31
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 55s 403ms/step - accuracy: 0.5143 - loss: 1.3806 - val_accuracy: 0.6141 - val_loss: 1.1088
# Epoch 21/31
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 57s 417ms/step - accuracy: 0.5473 - loss: 1.3268 - val_accuracy: 0.6385 - val_loss: 1.0592
# Epoch 22/31
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 55s 404ms/step - accuracy: 0.5659 - loss: 1.2776 - val_accuracy: 0.6640 - val_loss: 1.0200
# Epoch 23/31
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 58s 428ms/step - accuracy: 0.5881 - loss: 1.2297 - val_accuracy: 0.6780 - val_loss: 0.9864
# Epoch 24/31
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 56s 409ms/step - accuracy: 0.5956 - loss: 1.2077 - val_accuracy: 0.6845 - val_loss: 0.9622
# Epoch 25/31
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 92s 476ms/step - accuracy: 0.6042 - loss: 1.1602 - val_accuracy: 0.6975 - val_loss: 0.9335
# Epoch 26/31
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 54s 382ms/step - accuracy: 0.6320 - loss: 1.1341 - val_accuracy: 0.7024 - val_loss: 0.9167
# Epoch 27/31
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 58s 413ms/step - accuracy: 0.6396 - loss: 1.1033 - val_accuracy: 0.7069 - val_loss: 0.9003
# Epoch 28/31
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 66s 493ms/step - accuracy: 0.6385 - loss: 1.0798 - val_accuracy: 0.7149 - val_loss: 0.8826
# Epoch 29/31
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 71s 406ms/step - accuracy: 0.6570 - loss: 1.0483 - val_accuracy: 0.7164 - val_loss: 0.8701
# Epoch 30/31
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 56s 408ms/step - accuracy: 0.6687 - loss: 1.0215 - val_accuracy: 0.7169 - val_loss: 0.8590
# Epoch 31/31
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 58s 429ms/step - accuracy: 0.6746 - loss: 1.0047 - val_accuracy: 0.7189 - val_loss: 0.8476
#
# Starting final evaluation after fine-tuning EfficientNetB1...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 320ms/step - accuracy: 0.7230 - loss: 0.8610
#
# ========================================
#      Final Results After Fine-Tuning EfficientNetB1
# ========================================
# Loss: 0.8476
# Accuracy: 71.89%
# ========================================
#
# ==================================================
#      Detailed Classification Report
# ==================================================
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 18s 430ms/step
#               precision    recall  f1-score   support
#
#        akiec       0.47      0.14      0.21        65
#          bcc       0.56      0.33      0.41       103
#          bkl       0.49      0.34      0.40       220
#           df       0.14      0.17      0.16        23
#          mel       0.37      0.24      0.29       223
#           nv       0.79      0.94      0.86      1341
#         vasc       0.71      0.36      0.48        28
#
#     accuracy                           0.72      2003
#    macro avg       0.51      0.36      0.40      2003
# weighted avg       0.68      0.72      0.69      2003
#
#
# ==================================================
#      Confusion Matrix
# ==================================================
